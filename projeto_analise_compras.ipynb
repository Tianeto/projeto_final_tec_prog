# %%
import pandas as pd

# %% [markdown]
# https://www.kaggle.com/datasets/sohaibdevv/consumer-shopping-behavior-and-preference-study-2026

# %%
compras = pd.read_csv('compras_online_store.csv')

# %%
compras.shape
# Out:
# (11789, 25)

# %%
compras.head()
# Out:
#    age  monthly_income  daily_internet_hours  smartphone_usage_years  \
# 0   56          221111                   6.5                      12
# 1   69           96029                   8.2                      13
# 2   46           19055                   6.4                       4
# 3   32           53170                   6.4                      11
# 4   60          244016                   6.0                       5
#
#    social_media_hours  online_payment_trust_score  tech_savvy_score  \
# 0                 0.7                           1                 6
# 1                 2.7                           6                 9
# 2                 2.1                          10                 8
# 3                 0.7                           2                10
# 4                 0.7                           2                 5
#
#    monthly_online_orders  monthly_store_visits  avg_online_spend  ...  \
# ...

# %% [markdown]
# O arquivo trata-se de um conjunto de informações sobre compras online e em lojas fisicas, para um estudo comprativo entre as duas opções de compras.
# Ele possui 11789 linhas e 25 colunas.
# As colunas são: idade, renda mensal, horas diárias na internet, anos de uso do smartphone, horas nas redes sociais, nivel confiança em pagamento online, nível conhecimento tecnológico, pedidos online mensais, visitas lojas mensais, gasto médio online, importância devolução grátis, disponibilidade produto online, nível compra por impulso, nível necessidade de tocar sentir(avaliar fisicamente), nível lealdade marca, conscientização ambiental, nivel pressão tempo, genero, porte da cidade, preferências compras

# %% [markdown]
# Possíveis perguntas:
# 1. O nível de consciencia ambiental interfere na quantidade de compras online ou fisicas
# 2. A quantidade de anos de uso do smartphone influencia na quantidade de compras online
# 3. a quantidade de horas nas redes sociais interfere na quantidade de compras online
# 4. o nível de cohecimento tecnológico interfere na quantidade de compras em geral
# 5. O genero influencia da quantidade de compras em geral
# 6. quem mora em cidade de porte pequeno prefere comprar online ou fisicamente
# 7. quem mora em cidades de grande porte prefere qual tipo de canal de compras
# 8. quanto maior a renda, as compras online ou fisicas aumentam, comparar
# 9. quem tem maior impulso por comprar prefere comprar online ou fisicamente
# 10. Qual a influencia da idade na quantidade de compras online e físicas

# %%
# Nível de confiança em pagamentos online vai de 1 a 10
compras['online_payment_trust_score'].unique()
# Out:
# array([ 1,  6, 10,  2,  4,  5,  8,  7,  9,  3])

# %%
# Nível de conhecimento tecnológico vai de 1 a 10
compras['tech_savvy_score'].unique()
# Out:
# array([ 6,  9,  8, 10,  5,  7,  3,  1,  4,  2])

# %%
# Nível de importância de devolução grátis vai de 1 a 10
compras['free_return_importance'].unique()
# Out:
# array([ 7,  3,  4, 10,  2,  9,  6,  1,  5,  8])

# %%
# Nível de compra por impulso 1 a 10
compras['impulse_buying_score'].unique()
# Out:
# array([ 1,  9,  4,  8,  6, 10,  5,  7,  2,  3])

# %%
# Tipos de genero Masculino, feminino e outros
compras['gender'].unique()
# Out:
# <ArrowStringArray>
# ['Other', 'Male', 'Female']
# Length: 3, dtype: str

# %%
# Porte da cidade 1,2 e 3
compras['city_tier'].unique()
# Out:
# <ArrowStringArray>
# ['Tier 3', 'Tier 1', 'Tier 2']
# Length: 3, dtype: str

# %%
#Tipos de preferencia de compras Loja, Hibrido e Online
compras['shopping_preference'].unique()
# Out:
# <ArrowStringArray>
# ['Store', 'Hybrid', 'Online']
# Length: 3, dtype: str
